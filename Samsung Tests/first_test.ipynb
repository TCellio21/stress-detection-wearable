# %%
import pandas as pd

# %%
CSV_PATH = r"C:\Users\gloriosog\AndroidStudioProjects\StressDetect\server\data\session_2026-06-13_16-48-24.csv"                                                                                                                                       
df = pd.read_csv(CSV_PATH)                                                                                                                                                                                                                            
# Convert timestamp to seconds relative to session start
df['time_s'] = (df['timestamp_ms'] - df['timestamp_ms'].min()) / 1000

print(df.shape)
print(df['sensor'].value_counts())
df.head(10)
# Out:
# (16230, 9)
# sensor
# PPG          7800
# ACCEL        7800
# HR            313
# EDA           312
# SKIN_TEMP       5
# Name: count, dtype: int64
#     timestamp_ms sensor     v1   v2   v3  v4  v5  status  time_s
# 0  1781387305135    EDA  0.289  NaN  NaN NaN NaN     0.0   0.000
# 1  1781387305605     HR  0.000   []   [] NaN NaN     0.0   0.470
# 2  1781387306145    EDA  0.289  NaN  NaN NaN NaN     0.0   1.010
# 3  1781387306607     HR  0.000   []   [] NaN NaN     0.0   1.472
# 4  1781387307147    EDA  0.152  NaN  NaN NaN NaN     0.0   2.012
# 5  1781387307629     HR  0.000   []   [] NaN NaN     0.0   2.494
# 6  1781387308125    EDA  0.162  NaN  NaN NaN NaN     0.0   2.990
# 7  1781387308631     HR  0.000   []   [] NaN NaN     0.0   3.496
# 8  1781387309152    EDA  0.162  NaN  NaN NaN NaN     0.0   4.017
# 9  1781387309606     HR  0.000   []   [] NaN NaN     0.0   4.471
